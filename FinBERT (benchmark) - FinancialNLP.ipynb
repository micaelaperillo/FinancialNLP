# %% [markdown]
# # FinBERT (benchmark)

# %% [markdown]
# ### Environment configuration

# %%
# !pip install -qU transformers accelerate datasets==2.16.0 watermark textattack
# !pip install pyarrow
# !pip install "numpy<2"
# !pip install -q pandas tqdm

# %reload_ext watermark
# %watermark -vmp transformers,datasets,torch,numpy,pandas,tqdm

import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (18.1.0)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.12/dist-packages (1.26.4)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1198010341.py in <cell line: 0>()
#       5
#       6 get_ipython().run_line_magic('reload_ext', 'watermark')
# ----> 7 get_ipython().run_line_magic('watermark', '-vmp transformers,datasets,torch,numpy,pandas,tqdm')
#       8
#       9 import torch
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2416                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2417             with self.builtin_trap:
# -> 2418                 result = fn(*args, **kwargs)
#    2419             return result
#    2420
#
# <decorator-gen-119> in watermark(self, line)
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.12/dist-packages/watermark/magic.py in watermark(self, line)
#      88         args['watermark_self'] = self
#      89
# ---> 90         formatted_text = watermark.watermark(**args)
#      91         print(formatted_text)
#      92
#
# /usr/local/lib/python3.12/dist-packages/watermark/watermark.py in watermark(author, email, github_username, website, current_date, datename, current_time, iso8601, timezone, updated, custom_time, python, packages, conda, hostname, machine, githash, gitrepo, gitbranch, watermark, iversions, gpu, watermark_self, globals_)
#     187             output.append(_get_pyversions())
#     188         if args['packages']:
# --> 189             output.append(_get_packages(args['packages']))
#     190         if args['conda']:
#     191             output.append(_get_conda_env())
#
# /usr/local/lib/python3.12/dist-packages/watermark/watermark.py in _get_packages(pkgs)
#     242 def _get_packages(pkgs):
#     243     packages = pkgs.split(",")
# --> 244     return {package: _get_package_version(package)
#     245             for package in packages}
#     246
#
# /usr/local/lib/python3.12/dist-packages/watermark/watermark.py in _get_package_version(pkg_name)
#     251         pkg_name = "sklearn"
#     252     try:
# --> 253         imported = importlib.import_module(pkg_name)
#     254     except ImportError:
#     255         version = "not installed"
#
# /usr/lib/python3.12/importlib/__init__.py in import_module(name, package)
#      88                 break
#      89             level += 1
# ---> 90     return _bootstrap._gcd_import(name[level:], package, level)
#      91
#      92
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.12/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /usr/local/lib/python3.12/dist-packages/datasets/__init__.py in <module>
#      20 __version__ = "2.16.0"
#      21
# ---> 22 from .arrow_dataset import Dataset
#      23 from .arrow_reader import ReadInstruction
#      24 from .builder import ArrowBasedBuilder, BeamBasedBuilder, BuilderConfig, DatasetBuilder, GeneratorBasedBuilder
#
# /usr/local/lib/python3.12/dist-packages/datasets/arrow_dataset.py in <module>
#      57 import fsspec
#      58 import numpy as np
# ---> 59 import pandas as pd
#      60 import pyarrow as pa
#      61 import pyarrow.compute as pc
#
# /usr/local/lib/python3.12/dist-packages/pandas/__init__.py in <module>
#      35     ) from _err
#      36
# ---> 37 from pandas._config import (
#      38     get_option,
#      39     set_option,
#
# /usr/local/lib/python3.12/dist-packages/pandas/_config/__init__.py in <module>
#      18     "warn_copy_on_write",
#      19 ]
# ---> 20 from pandas._config import config
#      21 from pandas._config import dates  # pyright: ignore[reportUnusedImport]  # noqa: F401
#      22 from pandas._config.config import (
#
# /usr/local/lib/python3.12/dist-packages/pandas/_config/config.py in <module>
#      66 import warnings
#      67
# ---> 68 from pandas._typing import (
#      69     F,
#      70     T,
#
# /usr/local/lib/python3.12/dist-packages/pandas/_typing.py in <module>
#     196     int,
#     197     np.ndarray,
# --> 198     np.random.Generator,
#     199     np.random.BitGenerator,
#     200     np.random.RandomState,
#
# /usr/local/lib/python3.12/dist-packages/numpy/__init__.py in __getattr__(attr)
#     335
#     336     def __dir__():
# --> 337         public_symbols = globals().keys() | {'testing'}
#     338         public_symbols -= {
#     339             "core", "matrixlib",
#
# /usr/local/lib/python3.12/dist-packages/numpy/random/__init__.py in <module>
#     178
#     179 # add these for module-freeze analysis (like PyInstaller)
# --> 180 from . import _pickle
#     181 from . import _common
#     182 from . import _bounded_integers
#
# /usr/local/lib/python3.12/dist-packages/numpy/random/_pickle.py in <module>
# ----> 1 from .mtrand import RandomState
#       2 from ._philox import Philox
#       3 from ._pcg64 import PCG64, PCG64DXSM
#       4 from ._sfc64 import SFC64
#       5
#
# numpy/random/mtrand.pyx in init numpy.random.mtrand()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %% [markdown]
# ## Dataset
#
# https://huggingface.co/datasets/takala/financial_phrasebank

# %%
from datasets import load_dataset, DatasetDict, ClassLabel, Dataset

dataset = load_dataset("takala/financial_phrasebank", "sentences_50agree")

full_dataset = dataset['train']

split_dataset = full_dataset.train_test_split(test_size=0.2, seed=42)
test_valid_split = split_dataset['test'].train_test_split(test_size=0.5, seed=42)

dataset = DatasetDict({
    'train': split_dataset['train'],
    'validation': test_valid_split['train'],
    'test': test_valid_split['test']
})
# Out:
# /usr/local/lib/python3.12/dist-packages/datasets/load.py:1429: FutureWarning: The repository for takala/financial_phrasebank contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/takala/financial_phrasebank
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(

# %%
label_names = dataset["train"].features["label"].names
label2id = {name: dataset["train"].features["label"].str2int(name) for name in label_names}
id2label = {id: label for label, id in label2id.items()}

print("Label names: ", label_names)
print("Label ids: ", label2id["negative"], label2id['neutral'], label2id["positive"])
# Out:
# Label names:  ['negative', 'neutral', 'positive']
# Label ids:  0 1 2

# %% [markdown]
# ## FinBERT
#
# [finBERT](https://huggingface.co/ProsusAI/finbert)

# %%
from transformers import pipeline

sentiment_clf = pipeline(
    model="ProsusAI/finbert",
    device=device, batch_size=32
)
# Out:
# Device set to use cuda

# %%
from transformers.pipelines.pt_utils import KeyDataset

test_outputs = []
for output in sentiment_clf(KeyDataset(dataset["test"], "sentence"), top_k=None):
    test_outputs.append(output[0])

print(f"Inference complete. Total predictions: {len(test_outputs)}")
# Out:
# Inference complete. Total predictions: 485

# %% [markdown]
# ## Metrics

# %%
from sklearn.metrics import classification_report

true_labels = dataset["test"]["label"]

predicted_labels = [label2id[output['label']] for output in test_outputs]

print("\n--- Final Test Results (FinBERT Zero-Shot Baseline via Pipeline) ---")

report = classification_report(
    y_true=true_labels,
    y_pred=predicted_labels,
    target_names=label_names,
    digits=4
)

print(report)
# Out:
# --- Final Test Results (FinBERT Zero-Shot Baseline via Pipeline) ---
#               precision    recall  f1-score   support
#
#     negative     0.8028    0.9500    0.8702        60
#      neutral     0.9603    0.8582    0.9064       282
#     positive     0.8086    0.9161    0.8590       143
#
#     accuracy                         0.8866       485
#    macro avg     0.8573    0.9081    0.8785       485
# weighted avg     0.8961    0.8866    0.8879       485

# %% [markdown]
# ### Interpretacion de las Metricas
#
# - **Precision**: De todas las veces que el modelo dijo que algo era Negative, el 80.28% de las veces fue correcto.
#
# - **Recall**: De todos los titulares que eran realmente Negative (60 en total), el modelo logró identificar correctamente al 95.00% de ellos.En resumen, el 88.66% de acierto global es tu métrica principal, pero el resto de la tabla te permite argumentar que, incluso sin fine-tuning, el modelo especializado ya tiene un rendimiento muy robusto.
